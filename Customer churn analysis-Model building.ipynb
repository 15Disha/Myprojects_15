# %% [markdown]
# CUSTOMER CHURN PREDICTION (MODEL BUILDING PART)

# %%
import pandas as pd
from sklearn import metrics
from imblearn.combine import SMOTEENN
from sklearn.model_selection import train_test_split
from sklearn.metrics import recall_score
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

# %%
df=pd.read_csv("D:\\telco_churn.csv")

# %%
df.head()
# Out:
#    Unnamed: 0  SeniorCitizen  MonthlyCharges  TotalCharges  Churn  \
# 0           0              0           29.85         29.85      0
# 1           1              0           56.95       1889.50      0
# 2           2              0           53.85        108.15      1
# 3           3              0           42.30       1840.75      0
# 4           4              0           70.70        151.65      1
#
#    gender_Female  gender_Male  Partner_No  Partner_Yes  Dependents_No  ...  \
# 0              1            0           0            1              1  ...
# 1              0            1           1            0              1  ...
# 2              0            1           1            0              1  ...
# 3              0            1           1            0              1  ...
# 4              1            0           1            0              1  ...
#
#    PaymentMethod_Bank transfer (automatic)  \
# 0                                        0
# ...

# %%
df=df.drop('Unnamed: 0',axis=1)

# %%
df.head()
# Out:
#    SeniorCitizen  MonthlyCharges  TotalCharges  Churn  gender_Female  \
# 0              0           29.85         29.85      0              1
# 1              0           56.95       1889.50      0              0
# 2              0           53.85        108.15      1              0
# 3              0           42.30       1840.75      0              0
# 4              0           70.70        151.65      1              1
#
#    gender_Male  Partner_No  Partner_Yes  Dependents_No  Dependents_Yes  ...  \
# 0            0           0            1              1               0  ...
# 1            1           1            0              1               0  ...
# 2            1           1            0              1               0  ...
# 3            1           1            0              1               0  ...
# 4            0           1            0              1               0  ...
#
#    PaymentMethod_Bank transfer (automatic)  \
# 0                                        0
# ...

# %%
#creating x variables

x=df.drop('Churn',axis=1)
x
# Out:
#       SeniorCitizen  MonthlyCharges  TotalCharges  gender_Female  gender_Male  \
# 0                 0           29.85         29.85              1            0
# 1                 0           56.95       1889.50              0            1
# 2                 0           53.85        108.15              0            1
# 3                 0           42.30       1840.75              0            1
# 4                 0           70.70        151.65              1            0
# ...             ...             ...           ...            ...          ...
# 7027              0           84.80       1990.50              0            1
# 7028              0          103.20       7362.90              1            0
# 7029              0           29.60        346.45              1            0
# 7030              1           74.40        306.60              0            1
# 7031              0          105.65       6844.50              0            1
#
# ...

# %%
#Creating y variable 

y=df['Churn']
y
# Out:
# 0       0
# 1       0
# 2       1
# 3       0
# 4       1
#        ..
# 7027    0
# 7028    0
# 7029    0
# 7030    1
# 7031    0
# Name: Churn, Length: 7032, dtype: int64

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %% [markdown]
# **ALGORITHMS**

# %% [markdown]
# Decision Tree Classifier

# %%
model1=DecisionTreeClassifier()

# %%
model1.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
pred=model1.predict(x_test)

# %%
print(classification_report(y_test,pred,labels=[0,1]))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.81      0.81      0.81      1035
#            1       0.47      0.47      0.47       372
#
#     accuracy                           0.72      1407
#    macro avg       0.64      0.64      0.64      1407
# weighted avg       0.72      0.72      0.72      1407

# %%
print(confusion_matrix(y_test,pred))
# Out:
# [[841 194]
#  [199 173]]

# %% [markdown]
# Random Forest Classifier

# %%
model2=RandomForestClassifier()

# %%
model2.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
pred=model2.predict(x_test)

# %%
pred
# Out:
# array([0, 0, 1, ..., 1, 0, 0], dtype=int64)

# %%
print(classification_report(y_test,pred,labels=[0,1]))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.81      0.89      0.85      1035
#            1       0.59      0.43      0.50       372
#
#     accuracy                           0.77      1407
#    macro avg       0.70      0.66      0.67      1407
# weighted avg       0.75      0.77      0.76      1407

# %%
print(confusion_matrix(y_test,pred))
# Out:
# [[922 113]
#  [211 161]]

# %%
samp=SMOTEENN()
x_resampled,y_resampled=samp.fit_resample(x,y)

# %%
xr_train,xr_test,yr_train,yr_test=train_test_split(x_resampled,y_resampled,test_size=0.2)

# %% [markdown]
# Decision Tree Classifier

# %%
model1_smote=DecisionTreeClassifier()

# %%
model1_smote.fit(xr_train,yr_train)
# Out:
# DecisionTreeClassifier()

# %%
pred1_smote=model1_smote.predict(xr_test)

# %%
print(classification_report(yr_test,pred1_smote,labels=[0,1]))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.93      0.94       522
#            1       0.94      0.96      0.95       649
#
#     accuracy                           0.95      1171
#    macro avg       0.95      0.94      0.94      1171
# weighted avg       0.95      0.95      0.95      1171

# %%
print(confusion_matrix(yr_test,pred1_smote))
# Out:
# [[484  38]
#  [ 26 623]]

# %%
model1_smote.score(xr_test,yr_test)
# Out:
# 0.9453458582408198

# %% [markdown]
# Random Forest Classifier

# %%
model2_smote=RandomForestClassifier()

# %%
model2_smote.fit(xr_train,yr_train)
# Out:
# RandomForestClassifier()

# %%
pred2_smote=model2_smote.predict(xr_test)

# %%
print(classification_report(yr_test,pred2_smote,labels=[0,1]))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.94      0.95       522
#            1       0.95      0.97      0.96       649
#
#     accuracy                           0.96      1171
#    macro avg       0.96      0.96      0.96      1171
# weighted avg       0.96      0.96      0.96      1171

# %%
print(confusion_matrix(yr_test,pred2_smote))
# Out:
# [[492  30]
#  [ 21 628]]

# %%
model2_smote.score(xr_test,yr_test)
# Out:
# 0.9564474807856533

# %%
#saving our model

import pickle

# %%
filename='model.sav'

# %%
pickle.dump(model2_smote,open(filename,'wb'))

# %%
load_model=pickle.load(open(filename,'rb'))

# %%
load_model.score(xr_test,yr_test)
# Out:
# 0.9564474807856533

# %% [markdown]
# **DEPLOYMENT OF CODE**
